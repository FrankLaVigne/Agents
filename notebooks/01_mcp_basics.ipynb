# %% [markdown]
# # 01 - MCP Basics\n\nThis notebook walks through the MCP samples in this repo.

# %% [markdown]
# ## Goals\n\n1. Understand raw MCP server/client flow.\n2. Run the raw sample.\n3. Run the SDK sample (optional).

# %%
from pathlib import Path\nsorted([p.name for p in Path('.').iterdir() if p.is_file()])

# %% [markdown]
# ## Raw MCP: run the agent\n\nThis launches `mcp/raw/mcp_server.py`, initializes, lists tools, and enters interactive mode.

# %%
import subprocess, textwrap\ncmd = "printf '/quit\\n' | python3 mcp/raw/sample_agent.py"\nresult = subprocess.run(cmd, shell=True, text=True, capture_output=True)\nprint(result.stdout[:2000])

# %% [markdown]
# ## SDK MCP (optional)\n\nInstall then run:\n\n- `python3 -m pip install "mcp[cli]"`\n- `python3 mcp/sdk/sdk_agent.py`
