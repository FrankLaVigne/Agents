# %% [markdown]
# # 02 - A2A and ACP Basics\n\nThis notebook explains and exercises the A2A and ACP samples.

# %% [markdown]
# ## Install dependencies\n\n- A2A: `python3 -m pip install a2a-sdk uvicorn httpx`\n- ACP: `python3 -m pip install acp-sdk uvicorn httpx`

# %% [markdown]
# ## A2A quick run\n\nTerminal 1: `python3 a2a/a2a_server.py`\nTerminal 2: `python3 a2a/a2a_client.py`

# %% [markdown]
# ## ACP quick run\n\nTerminal 1: `python3 acp/acp_server.py`\nTerminal 2: `python3 acp/acp_client.py`

# %%
from pathlib import Path\nfor name in ['a2a/a2a_server.py','a2a/a2a_client.py','acp/acp_server.py','acp/acp_client.py']:\n    print(name, 'exists:', Path(name).exists())
