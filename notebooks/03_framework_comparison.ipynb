# %% [markdown]
# # 03 - Framework Comparison\n\nUse this notebook as a practical decision guide for MCP vs A2A vs ACP.

# %% [markdown]
# ## Summary table

# %%
from textwrap import dedent\ntable = dedent('''\nFramework | Best fit | Transport | This repo files\n--- | --- | --- | ---\nRaw MCP | Learn wire protocol | stdio JSON-RPC | mcp/raw/mcp_server.py, mcp/raw/sample_agent.py\nMCP SDK | Production MCP tool servers | stdio (and others) | mcp/sdk/sdk_mcp_server.py, mcp/sdk/sdk_agent.py\nA2A | Agent-to-agent interoperability | HTTP | a2a/a2a_server.py, a2a/a2a_client.py\nACP | Agent app protocol workflows | HTTP | acp/acp_server.py, acp/acp_client.py\n''').strip()\nprint(table)

# %% [markdown]
# ## Suggested progression\n\n1. Start with raw MCP to understand basics.\n2. Move to MCP SDK for maintainability.\n3. Add A2A/ACP when you need cross-agent protocols over HTTP.
